# %% [markdown]
# This file is made to practice Numpy, pandas and other important libraries  used in machine learning

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
original_img = plt.imread('Snapchat-1756639198.jpg')

# %%
plt.imshow(original_img)

# %%
original_img = original_img/255

x_img = np.reshape(original_img, (original_img.shape[0] * original_img.shape[1], 3))

# %%
original_img.shape
# Out:
# (973, 492, 3)

# %%
k = 255
max_iters = 64

from mimetypes import init
from sklearn.cluster import KMeans

k_means = KMeans(n_clusters=k , init = 'k-means++' )
k_means.fit(x_img, max_iters)
# Out:
# KMeans(n_clusters=255)

# %%
centroids = k_means.cluster_centers_
print(centroids)

idx = k_means.labels_
print(idx.shape)
# Out:
# [[0.62323819 0.62577717 0.67311025]
#  [0.19800915 0.211638   0.21236604]
#  [0.37741246 0.43242293 0.46797964]
#  [0.11954987 0.10381037 0.08774835]
#  [0.33099698 0.32491417 0.32016774]
#  [0.42212265 0.54174265 0.58457424]
#  [0.48381726 0.37011684 0.35489193]
#  [0.00256475 0.00451444 0.00155505]
#  [0.55551991 0.54979444 0.59559315]
#  [0.33509825 0.271452   0.21069053]
#  [0.17332739 0.1363981  0.12795603]
#  [0.31821737 0.3569857  0.37543722]
#  [0.29307491 0.33005194 0.34320893]
#  [0.22490933 0.25697184 0.26388127]
#  [0.22850135 0.21354554 0.1740446 ]
#  [0.49023887 0.52665531 0.57853587]
#  [0.28720474 0.37471227 0.40826083]
#  [0.41524487 0.33893395 0.28422928]
#  [0.41005034 0.48292631 0.53466417]
#  [0.50788874 0.43554745 0.40599889]
#  [0.60907298 0.58152402 0.61933197]
#  [0.27468358 0.18048773 0.22473137]
#  [0.17051607 0.17830992 0.17357165]
#  [0.14537889 0.12725341 0.11309774]
#  [0.29797207 0.25383129 0.19912713]
#  [0.33334669 0.4124962  0.45798669]
# ...

# %%
x_recovered = centroids[idx, :]

x_recovered = np.reshape(x_recovered, original_img.shape)

# %%
fig, ax = plt.subplots(1,2, figsize = (16,16))
plt.axis('off')


ax[0].imshow(original_img)
ax[0].set_title('Original')
ax[0].set_axis_off()


ax[1].imshow(x_recovered)
ax[1].set_title('Compressed with %d colors' %k)
ax[1].set_axis_off()

print(x_recovered.shape)
# Out:
# (973, 492, 3)

# %%
fig, bx = plt.subplots(1, figsize = (8,8))

bx.imshow(x_recovered)
bx.set_axis_off()
